# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
metrics = [
    [10, 1.095400,0.930802,0.492256],
    [20, 0.909400,0.842801,0.591879],
    [30, 0.763000,0.718760,0.662202],
    [40, 0.735900, 0.653599, 0.686061],
    [50, 0.614500, 0.604578, 0.717455],
    [60, 0.454500, 0.633975, 0.711595],
    [70, 0.703400, 0.696485, 0.693596],
    [80, 0.584600, 0.553050, 0.763081],
    [90, 0.460600, 0.475768, 0.829636],
    [100, 0.432400, 0.546592, 0.758476],
    [110, 0.548200, 0.335417, 0.864797],
    [120, 0.487700, 0.241251, 0.910004],
    [130, 0.309200, 0.355466, 0.895354],
    [140, 0.337700, 0.364726, 0.875680],
    [150, 0.183300, 0.232142, 0.935119],
    [160, 0.237600, 0.352137, 0.917539],
    [170, 0.197400, 0.278607, 0.932189],
    [180, 0.281000, 0.249816, 0.940561],
    [190, 0.155200, 0.136609, 0.965676],
    [200, 0.133300, 0.222673, 0.951863],
    [210, 0.150000, 0.154932, 0.965257],
    [220, 0.201300, 0.188947, 0.959816],
    [230, 0.154500, 0.128872, 0.973629],
    [240, 0.221800, 0.107373, 0.977815],
    [250, 0.081400, 0.115241, 0.977815],
    [260, 0.019200, 0.131225, 0.974885],
    [270, 0.242400, 0.133230, 0.972373],
    [280, 0.061500, 0.119540, 0.974466],
    [290, 0.216100, 0.108672, 0.976978],
    [300, 0.259700, 0.107746, 0.976978]
]

# %%
metrics_df = pd.DataFrame(metrics, columns=["Step", "Training Loss", "Validation Loss", "Accuracy"])
metrics_df
# Out:
#     Step  Training Loss  Validation Loss  Accuracy
# 0     10         1.0954         0.930802  0.492256
# 1     20         0.9094         0.842801  0.591879
# 2     30         0.7630         0.718760  0.662202
# 3     40         0.7359         0.653599  0.686061
# 4     50         0.6145         0.604578  0.717455
# 5     60         0.4545         0.633975  0.711595
# 6     70         0.7034         0.696485  0.693596
# 7     80         0.5846         0.553050  0.763081
# 8     90         0.4606         0.475768  0.829636
# 9    100         0.4324         0.546592  0.758476
# 10   110         0.5482         0.335417  0.864797
# 11   120         0.4877         0.241251  0.910004
# 12   130         0.3092         0.355466  0.895354
# 13   140         0.3377         0.364726  0.875680
# 14   150         0.1833         0.232142  0.935119
# 15   160         0.2376         0.352137  0.917539
# 16   170         0.1974         0.278607  0.932189
# ...

# %%
training_loss = metrics_df["Training Loss"]
validation_loss = metrics_df["Validation Loss"]
accuracy = metrics_df["Accuracy"]
steps = metrics_df["Step"]

# %%
# Plotting the curves simultaneously
sns.set(rc={'figure.figsize':(11.7,8.27)}, font_scale=1.5)

plt.plot(steps, training_loss, color='b', label='Training Loss')
plt.plot(steps, validation_loss, color='g', label='Validation Loss')
plt.plot(steps, accuracy, color='r', label='Accuracy')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Steps")
plt.title("wav2vec2 training metrics - Instrument - Flute/Sitar/Sarod")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend(loc="best", fontsize='large', title_fontsize='large')
#plt.rcParams.update({'font.size': 25})

# To load the display window
plt.savefig("instrument-wav2vec2-training.png")
plt.show()

# %%
metrics_emotion_2_class = [
    [10, 0.734300, 0.708968, 0.509615],
    [20, 0.713700, 0.687604, 0.581731],
    [30, 0.696700, 0.692196, 0.509615],
    [40, 0.700300, 0.685142, 0.569712],
    [50, 0.660300, 0.771145, 0.509615],
    [60, 0.665100, 0.686782, 0.593750],
    [70, 0.660300, 0.720681, 0.581731],
    [80, 0.726100, 0.741007, 0.574519],
    [90, 0.626100, 0.678341, 0.591346],
    [100, 0.666500, 0.691780, 0.586538],
    [110, 0.633800, 0.659806, 0.608173],
    [120, 0.620200, 0.631067, 0.622596],
    [130, 0.684600, 0.618476, 0.661058],
    [140, 0.657000, 0.589590, 0.663462],
    [150, 0.580900, 0.565728, 0.706731],
    [160, 0.609000, 0.597583, 0.697115],
    [170, 0.593000, 0.520281, 0.750000],
    [180, 0.522000, 0.502877, 0.774038],
    [190, 0.565900, 0.565534, 0.764423],
    [200, 0.560300, 0.543131, 0.769231]
]

# %%
metrics_df = pd.DataFrame(metrics_emotion_2_class, columns=["Step", "Training Loss", "Validation Loss", "Accuracy"])
metrics_df
# Out:
#     Step  Training Loss  Validation Loss  Accuracy
# 0     10         0.7343         0.708968  0.509615
# 1     20         0.7137         0.687604  0.581731
# 2     30         0.6967         0.692196  0.509615
# 3     40         0.7003         0.685142  0.569712
# 4     50         0.6603         0.771145  0.509615
# 5     60         0.6651         0.686782  0.593750
# 6     70         0.6603         0.720681  0.581731
# 7     80         0.7261         0.741007  0.574519
# 8     90         0.6261         0.678341  0.591346
# 9    100         0.6665         0.691780  0.586538
# 10   110         0.6338         0.659806  0.608173
# 11   120         0.6202         0.631067  0.622596
# 12   130         0.6846         0.618476  0.661058
# 13   140         0.6570         0.589590  0.663462
# 14   150         0.5809         0.565728  0.706731
# 15   160         0.6090         0.597583  0.697115
# 16   170         0.5930         0.520281  0.750000
# ...

# %%
training_loss = metrics_df["Training Loss"]
validation_loss = metrics_df["Validation Loss"]
accuracy = metrics_df["Accuracy"]
steps = metrics_df["Step"]

# %%
# Plotting the curves simultaneously
sns.set(rc={'figure.figsize':(11.7,8.27)}, font_scale=1.5)

plt.plot(steps, training_loss, color='b', label='Training Loss')
plt.plot(steps, validation_loss, color='g', label='Validation Loss')
plt.plot(steps, accuracy, color='r', label='Accuracy')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Steps")
plt.title("wav2vec2 training metrics - Emotion - Happy/Sad")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend(loc="best", fontsize='large', title_fontsize='large')
#plt.rcParams.update({'font.size': 25})

# To load the display window
plt.savefig("emotion-2-class-wav2vec2-training.png")
plt.show()

# %%
metrics_emotion_4_class = [
    [10, 1.418800, 1.387003, 0.293856],
    [20, 1.411600, 1.359939, 0.304541],
    [30, 1.282100, 1.257665, 0.455922],
    [40, 1.300600, 1.237182, 0.460374],
    [50, 1.253700, 1.170132, 0.463936],
    [60, 1.198300, 1.171773, 0.382012],
    [70, 1.244000, 1.154141, 0.452360],
    [80, 1.110000, 1.197808, 0.476402],
    [90, 1.060700, 1.186485, 0.477293],
    [100, 1.260400, 1.129160, 0.456812],
    [110, 1.214000, 1.123951, 0.453250],
    [120, 1.018300, 1.173678, 0.461264],
    [130, 1.033000, 1.171955, 0.483526],
    [140, 1.395300, 1.143236, 0.495993],
    [150, 1.138000, 1.105389, 0.446126],
    [160, 1.028100, 1.093149, 0.485307],
    [170, 1.123000, 1.105664, 0.505788],
    [180, 1.057800, 1.067215, 0.504898],
    [190, 1.073300, 1.071149, 0.495993],
    [200, 1.010300, 1.072317, 0.498664]
]

# %%
metrics_df = pd.DataFrame(metrics_emotion_4_class, columns=["Step", "Training Loss", "Validation Loss", "Accuracy"])
metrics_df
# Out:
#     Step  Training Loss  Validation Loss  Accuracy
# 0     10         1.4188         1.387003  0.293856
# 1     20         1.4116         1.359939  0.304541
# 2     30         1.2821         1.257665  0.455922
# 3     40         1.3006         1.237182  0.460374
# 4     50         1.2537         1.170132  0.463936
# 5     60         1.1983         1.171773  0.382012
# 6     70         1.2440         1.154141  0.452360
# 7     80         1.1100         1.197808  0.476402
# 8     90         1.0607         1.186485  0.477293
# 9    100         1.2604         1.129160  0.456812
# 10   110         1.2140         1.123951  0.453250
# 11   120         1.0183         1.173678  0.461264
# 12   130         1.0330         1.171955  0.483526
# 13   140         1.3953         1.143236  0.495993
# 14   150         1.1380         1.105389  0.446126
# 15   160         1.0281         1.093149  0.485307
# 16   170         1.1230         1.105664  0.505788
# ...

# %%
training_loss = metrics_df["Training Loss"]
validation_loss = metrics_df["Validation Loss"]
accuracy = metrics_df["Accuracy"]
steps = metrics_df["Step"]

# %%
# Plotting the curves simultaneously
sns.set(rc={'figure.figsize':(11.7,8.27)}, font_scale=1.5)

plt.plot(steps, training_loss, color='b', label='Training Loss')
plt.plot(steps, validation_loss, color='g', label='Validation Loss')
plt.plot(steps, accuracy, color='r', label='Accuracy')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Steps")
plt.title("wav2vec2 training metrics - Emotion - Happy/Sad/Anxiety/Calm")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend(loc="best", fontsize='large', title_fontsize='large')
#plt.rcParams.update({'font.size': 25})

# To load the display window
plt.savefig("emotion-4-class-wav2vec2-training.png")
plt.show()

# %%
instru_metrics = [
    [0.99, 0.98, 0.98],
    [0.98, 0.98, 0.98],
    [0.95, 0.97, 0.96]
]

emo_2_class_metrics = [
    [0.48,      0.76,      0.59],
    [0.63,      0.74,      0.68],
    [0.56,      0.04,      0.07],
    [0.32,      0.32,      0.32]
]

emo_4_class_metrics = [
    [0.79,      0.65,      0.72],
    [0.71,      0.83,      0.77]
]

# %%
instrument_accuracy = [
    ["NB", 0.62018],
    ["GD", 0.86647],
    ["KNN", 0.92582],
    ["DT", 0.88724],
    ["RF",0.92142],
    ["SVM", 0.91395],
    ["LR", 0.87062],
    ["XGBoost", 0.93234],
    ["ANN", 0.89614],
    ["CNN", 0.92],
    ["wav2vec2", 0.97]
]

emotion_4_class_accuracy = [
    ["NB", 0.41662],
    ["GD", 0.48368],
    ["KNN", 0.73412],
    ["DT", 0.77567],
    ["RF", 0.8457],
    ["SVM", 0.65935],
    ["LR", 0.58813],
    ["XGBoost", 0.80297],
    ["ANN", 0.67893],
    ["CNN", 0.62],
    ["wav2vec2", 0.54]
]

emotion_2_class_accuracy = [
    ["NB",0.5905],
    ["GD", 0.68724],
    ["KNN", 0.80712],
    ["DT",0.83323],
    ["RF", 0.8],
    ["SVM", 0.74362],
    ["LR", 0.68487],
    ["XGBoost", 0.83442],
    ["ANN", 0.75668],
    ["CNN", 0.68],
    ["wav2vec2", 0.76]
]


instrument_df = pd.DataFrame(instrument_accuracy, columns=["Name", "Value"])
instrument_df.index = instrument_df.Name
instrument_df.drop(['Name'], axis=1, inplace=True)
emotion_4_df = pd.DataFrame(emotion_4_class_accuracy, columns=["Name", "Value"])
emotion_4_df.index = emotion_4_df.Name
emotion_4_df.drop(['Name'], axis=1, inplace=True)
emotion_2_df = pd.DataFrame(emotion_2_class_accuracy, columns=["Name", "Value"])
emotion_2_df.index = emotion_2_df.Name
emotion_2_df.drop(['Name'], axis=1, inplace=True)
emotion_2_df
# Out:
#             Value
# Name
# NB        0.59050
# GD        0.68724
# KNN       0.80712
# DT        0.83323
# RF        0.80000
# SVM       0.74362
# LR        0.68487
# XGBoost   0.83442
# ANN       0.75668
# CNN       0.68000
# wav2vec2  0.76000

# %%
list(emotion_2_df.index)
# Out:
# ['NB',
#  'GD',
#  'KNN',
#  'DT',
#  'RF',
#  'SVM',
#  'LR',
#  'XGBoost',
#  'ANN',
#  'CNN',
#  'wav2vec2']

# %%
labels = list(emotion_2_df.index)
instrument = list(instrument_df.Value)
emotion_4 = list(emotion_4_df.Value)
emotion_2 = list(emotion_2_df.Value)

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 3*width/4, instrument, width, label='Instrument Detection')
rects2 = ax.bar(x, emotion_4, width, label='Emotion Detection (Happy/Calm/Sad/Anxiety)')
rects3 = ax.bar(x + 3*width/4, emotion_2, width, label='Emotion Detection (Happy/Sad)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy by Classifiers')
ax.set_xticks(x, labels)
ax.legend(loc="lower center", fontsize='medium')

plt.xticks(rotation=45)

plt.savefig("accuracy-classifiers.png")
plt.show()
